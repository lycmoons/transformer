# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ### 训练过程中学习率的调度

# %%
lr_histories = np.load('outputs\lr_histories.npy')
steps = np.arange(1, len(lr_histories) + 1)
plt.plot(steps, lr_histories)
plt.xlabel("num_steps")
plt.ylabel("learning_rate")
plt.title("Learning Rate Schedule")
plt.grid(True)
plt.show()

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ### 训练过程中损失值的变化

# %%
loss_histories = np.load('outputs\loss_histories.npy')
epochs = np.arange(1, len(loss_histories) + 1)
plt.plot(epochs, loss_histories)
plt.xlabel("num_epochs")
plt.ylabel("loss")
plt.title("Training Loss Curve")
plt.grid(True)
plt.show()
